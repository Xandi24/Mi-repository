# %% [markdown]
# # Exercício 1

# %% [markdown]
# # Primeira Parte do Exercício

# %%
import numpy as np
import random
import time
import matplotlib.pyplot as plt
def func1(n):
    ti=time.time()
    A=np.random.rand(n)
    B=np.random.rand(n)
    i=random.random()
    j=random.random()
    C=i*A+j*B
    tf=time.time() -ti
    return tf
k=10**4
q=10**8
x=np.linspace(k, q, 4)
print(x)
y=np.array([])
for u in range(4,8):
    print(u)
    y=np.append(y,func1(10**u))

print(y)

plt.plot(x,y)
plt.grid()
plt.xlabel('entrada')
plt.ylabel('t[s]')
plt.show()

plt.loglog(x,y)
plt.grid()
plt.xlabel('entrada')
plt.ylabel('t[s]')
plt.show()
# Out:
# [1.000e+04 3.334e+07 6.667e+07 1.000e+08]
# 4
# 5
# 6
# 7
# [0.00070524 0.02470851 0.03075147 0.30136847]

# %% [markdown]
# # Segunda Parte do Exercício

# %%
def func2(n,m):
    ti=time.time()
    M=np.random.rand(n,n)
    for u in range(m-1):
        M=M@M
    
    tf=time.time()-ti
    return tf

X=np.array([])
X=np.linspace(10**2,10**4,4)
print(X)
y1,y2,y3=np.array([]),np.array([]),np.array([])

for u in range(1,5):
    y1=np.append(y1,func2(u*(10*3),2))
    y2=np.append(y2,func2(u*(10*3),3))
    y3=np.append(y3,func2(u*(10*3),4))
print(y)
plt.plot(X,y1,X,y2,X,y3)
plt.grid()
plt.xlabel('entrada')
plt.ylabel('t[s]')
plt.show()

plt.loglog(X,y1,X,y2,X,y3)
plt.grid()
plt.xlabel('entrada')
plt.ylabel('t[s]')
plt.show()
# Out:
# [  100.  3400.  6700. 10000.]
# [0.00070524 0.02470851 0.03075147 0.30136847]
