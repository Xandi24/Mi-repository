# %% [markdown]
# # Exercício 4

# %%
import numpy as np
import matplotlib.pyplot as plt

n=10*7 ##Referente ao número de sequências da função Xn=a*[Xn-1]*[1-Xn-1]
rng=40000 ##Valor usado para que sejam considerados um maior valor de números decimais
          ##    como valores de a
red=0.0001 ## escala usada nas funções para transformar os números de 0 a 40000
           ##em números de 0 a 4 com vários decimais 

## Procedimento que forma e retorna um vetor com os resultados da função Xn=a*[Xn-1]*[1-Xn-1]
##para um valor em a, sendo que cada elemento do vetor guardará o valor para a uam sequência
##de n repetições 

def make_list(a,N):
    x=[0.1]
    for i in range (0,N):
        x.append(a*x[i]*(1-x[i]))
    return x

x,y=[],[]

##  Função que:
##  1:guarda em um vetor x os valores de a considerados
##  2:faz um vetor em que cada elemento é também um vetor[lista] que guarda
##se diferenciando apenas cada um no valor do termo a considerado

for i in range (0,rng+1):
    x.append(i*red)
    y.append(make_list(i*red,n))

plt.plot(x,y, ls='',marker=',')
plt.grid()
plt.xlabel('Valores de "a"')
plt.ylabel('Possiveis valores da sequencia')
plt.title('Grafico de bifurcacoes')
plt.show()
